# %% [markdown]
# <a href="https://colab.research.google.com/github/michael111999/ps-8-michael111999/blob/main/sharks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
summ=0
sumf=0

data = pd.read_csv('sharks.csv')
data.dropna()
data=data.rename(columns={"Fatal (Y/N)": "deaths"})

data=data.groupby("Sex").size()
data


data.plot(kind="bar")

plt.xlabel("Sex")
plt.ylabel("amount of attacks")
plt.title("Shark attacks by gender")
plt.show()
